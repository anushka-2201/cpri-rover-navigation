# %%
# !git clone https://github.com/Turoad/CLRNet.git
# %cd CLRNet
# Out:
# Cloning into 'CLRNet'...
# remote: Enumerating objects: 171, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 171 (delta 29), reused 26 (delta 26), pack-reused 94 (from 1)
# Receiving objects: 100% (171/171), 321.29 KiB | 8.45 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/CLRNet

# %%
# !pip install -r requirements.txt
# !python setup.py build develop
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.8.0 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0, 2.12.0, 2.12.1)
# ERROR: No matching distribution found for torch==1.8.0
# /usr/local/lib/python3.12/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'tests_require'
#   warnings.warn(msg)
# running build
# ...

# %%
# Ye commands automatically requirements.txt se torch aur torchvision hata dengi
# !sed -i '/torch/d' requirements.txt
# !sed -i '/torchvision/d' requirements.txt

# Ab baaki bachi hui dependencies install karo
# !pip install -r requirements.txt
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# Ye command file mein jahan bhi 'sklearn' likha hai, usko 'scikit-learn' bana degi
# !sed -i 's/sklearn/scikit-learn/g' requirements.txt

# Ab wapas se requirements install kar lo
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.1/349.1 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.0/192.0 kB 19.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.2/222.2 kB 24.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 25.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 6.8 MB/s eta 0:00:00
# ...

# %%
# !python setup.py build develop
# Out:
# /usr/local/lib/python3.12/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'tests_require'
#   warnings.warn(msg)
# running build
# running build_py
# copying clrnet/__init__.py -> build/lib.linux-x86_64-cpython-312/clrnet
# copying clrnet/models/registry.py -> build/lib.linux-x86_64-cpython-312/clrnet/models
# copying clrnet/models/__init__.py -> build/lib.linux-x86_64-cpython-312/clrnet/models
# ...

# %%
# 1. C++ aur CUDA files mein purane syntax ko naye syntax se replace karo
# !sed -i 's/\.type()/.scalar_type()/g' clrnet/ops/csrc/*.cu
# !sed -i 's/\.type()/.scalar_type()/g' clrnet/ops/csrc/*.cpp

# 2. Ab wapas se build try karo (Is baar NMS kernel aaram se compile ho jana chahiye)
# !python setup.py build develop
# Out:
# /usr/local/lib/python3.12/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'tests_require'
#   warnings.warn(msg)
# running build
# running build_py
# copying clrnet/__init__.py -> build/lib.linux-x86_64-cpython-312/clrnet
# copying clrnet/models/registry.py -> build/lib.linux-x86_64-cpython-312/clrnet/models
# copying clrnet/models/__init__.py -> build/lib.linux-x86_64-cpython-312/clrnet/models
# ...

# %%
# C++ aur CUDA files mein AT_CHECK ko TORCH_CHECK se replace karo
# !sed -i 's/AT_CHECK/TORCH_CHECK/g' clrnet/ops/csrc/*.cpp
# !sed -i 's/AT_CHECK/TORCH_CHECK/g' clrnet/ops/csrc/*.cu

# Wapas se build try karo
# !python setup.py build develop
# Out:
# /usr/local/lib/python3.12/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/dist.py:261: UserWarning: Unknown distribution option: 'tests_require'
#   warnings.warn(msg)
# running build
# running build_py
# copying clrnet/__init__.py -> build/lib.linux-x86_64-cpython-312/clrnet
# copying clrnet/models/registry.py -> build/lib.linux-x86_64-cpython-312/clrnet/models
# copying clrnet/models/__init__.py -> build/lib.linux-x86_64-cpython-312/clrnet/models
# ...
